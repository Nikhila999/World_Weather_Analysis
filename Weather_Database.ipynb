# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | souillac
# Processing Record 3 of Set 1 | minas
# Processing Record 4 of Set 1 | shu
# Processing Record 5 of Set 1 | mahibadhoo
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | ambovombe
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | orsha
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | mahebourg
# Processing Record 12 of Set 1 | san quintin
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | geraldton
# Processing Record 16 of Set 1 | kobyzhcha
# Processing Record 17 of Set 1 | nouakchott
# Processing Record 18 of Set 1 | tuktoyaktuk
# Processing Record 19 of Set 1 | bowen
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | cah ab
# City not found. Skipping...
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | mayuge
# Processing Record 29 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 1 | imbituba
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | hellendoorn
# Processing Record 33 of Set 1 | lavrentiya
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 1 | trelew
# Processing Record 38 of Set 1 | saint george
# Processing Record 39 of Set 1 | castro
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 42 of Set 1 | vila velha
# Processing Record 43 of Set 1 | chimore
# Processing Record 44 of Set 1 | torbay
# Processing Record 45 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 1 | siocon
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | cozumel
# Processing Record 49 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 50 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 2 | lompoc
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | luanda
# Processing Record 5 of Set 2 | saint anthony
# Processing Record 6 of Set 2 | oranjemund
# Processing Record 7 of Set 2 | saldanha
# Processing Record 8 of Set 2 | sao filipe
# Processing Record 9 of Set 2 | oktyabrskiy
# Processing Record 10 of Set 2 | puerto carreno
# Processing Record 11 of Set 2 | ahuimanu
# Processing Record 12 of Set 2 | jinchang
# Processing Record 13 of Set 2 | cherskiy
# Processing Record 14 of Set 2 | bahia honda
# Processing Record 15 of Set 2 | san cristobal
# Processing Record 16 of Set 2 | pemangkat
# Processing Record 17 of Set 2 | palmer
# Processing Record 18 of Set 2 | warrington
# Processing Record 19 of Set 2 | elko
# Processing Record 20 of Set 2 | bacabal
# Processing Record 21 of Set 2 | lorengau
# Processing Record 22 of Set 2 | tiruchchendur
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | labuhan
# Processing Record 25 of Set 2 | alofi
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | goure
# Processing Record 28 of Set 2 | husavik
# Processing Record 29 of Set 2 | matay
# Processing Record 30 of Set 2 | nawa
# Processing Record 31 of Set 2 | hualmay
# Processing Record 32 of Set 2 | aykhal
# Processing Record 33 of Set 2 | centralia
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | lasa
# Processing Record 36 of Set 2 | chokurdakh
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | bhainsdehi
# Processing Record 39 of Set 2 | bernalillo
# Processing Record 40 of Set 2 | bondo
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | gambela
# Processing Record 43 of Set 2 | sao joao da barra
# Processing Record 44 of Set 2 | abong mbang
# Processing Record 45 of Set 2 | huilong
# Processing Record 46 of Set 2 | sampit
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | yellowknife
# Processing Record 49 of Set 2 | naze
# Processing Record 50 of Set 2 | buraydah
# Processing Record 1 of Set 3 | uhlove
# Processing Record 2 of Set 3 | dingle
# Processing Record 3 of Set 3 | provideniya
# Processing Record 4 of Set 3 | airai
# Processing Record 5 of Set 3 | constitucion
# Processing Record 6 of Set 3 | bethel
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | carman
# Processing Record 9 of Set 3 | albany
# Processing Record 10 of Set 3 | pisco
# Processing Record 11 of Set 3 | teguise
# Processing Record 12 of Set 3 | hovd
# Processing Record 13 of Set 3 | vao
# Processing Record 14 of Set 3 | chapais
# Processing Record 15 of Set 3 | san lorenzo
# Processing Record 16 of Set 3 | iracoubo
# Processing Record 17 of Set 3 | baturaja
# Processing Record 18 of Set 3 | coahuayana
# Processing Record 19 of Set 3 | kaitangata
# Processing Record 20 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 3 | gwanda
# Processing Record 22 of Set 3 | bluff
# Processing Record 23 of Set 3 | marzuq
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | banda aceh
# Processing Record 26 of Set 3 | kununurra
# Processing Record 27 of Set 3 | hami
# Processing Record 28 of Set 3 | mugur-aksy
# Processing Record 29 of Set 3 | libertador general san martin
# Processing Record 30 of Set 3 | nanortalik
# Processing Record 31 of Set 3 | victoria
# Processing Record 32 of Set 3 | lashio
# Processing Record 33 of Set 3 | mareeba
# Processing Record 34 of Set 3 | kavaratti
# Processing Record 35 of Set 3 | mount gambier
# Processing Record 36 of Set 3 | atuona
# Processing Record 37 of Set 3 | dikson
# Processing Record 38 of Set 3 | iquique
# Processing Record 39 of Set 3 | changying
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | prince rupert
# Processing Record 42 of Set 3 | makakilo city
# Processing Record 43 of Set 3 | krasnooktyabrskiy
# Processing Record 44 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 3 | ilulissat
# Processing Record 46 of Set 3 | cap-aux-meules
# Processing Record 47 of Set 3 | arraial do cabo
# Processing Record 48 of Set 3 | sedelnikovo
# City not found. Skipping...
# Processing Record 49 of Set 3 | hithadhoo
# Processing Record 50 of Set 3 | aksu
# Processing Record 1 of Set 4 | vaini
# Processing Record 2 of Set 4 | poum
# Processing Record 3 of Set 4 | saint-philippe
# Processing Record 4 of Set 4 | ribeira grande
# Processing Record 5 of Set 4 | vanavara
# Processing Record 6 of Set 4 | aketi
# Processing Record 7 of Set 4 | monrovia
# Processing Record 8 of Set 4 | east london
# Processing Record 9 of Set 4 | correia pinto
# Processing Record 10 of Set 4 | port-cartier
# Processing Record 11 of Set 4 | shache
# Processing Record 12 of Set 4 | imphal
# Processing Record 13 of Set 4 | luderitz
# Processing Record 14 of Set 4 | saint-pierre
# Processing Record 15 of Set 4 | camacha
# Processing Record 16 of Set 4 | avarua
# Processing Record 17 of Set 4 | cap malheureux
# Processing Record 18 of Set 4 | hamilton
# Processing Record 19 of Set 4 | alghero
# Processing Record 20 of Set 4 | longyearbyen
# Processing Record 21 of Set 4 | svetlyy
# Processing Record 22 of Set 4 | xining
# Processing Record 23 of Set 4 | saskylakh
# Processing Record 24 of Set 4 | vawkavysk
# Processing Record 25 of Set 4 | tynda
# Processing Record 26 of Set 4 | quatre cocos
# Processing Record 27 of Set 4 | takoradi
# Processing Record 28 of Set 4 | carnarvon
# Processing Record 29 of Set 4 | vila franca do campo
# Processing Record 30 of Set 4 | san gabriel casa blanca
# Processing Record 31 of Set 4 | borba
# Processing Record 32 of Set 4 | paramirim
# Processing Record 33 of Set 4 | bilma
# Processing Record 34 of Set 4 | port hedland
# Processing Record 35 of Set 4 | kalmunai
# Processing Record 36 of Set 4 | esperance
# Processing Record 37 of Set 4 | gat
# Processing Record 38 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 4 | talnakh
# Processing Record 40 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 41 of Set 4 | mahuva
# Processing Record 42 of Set 4 | marienburg
# Processing Record 43 of Set 4 | strezhevoy
# Processing Record 44 of Set 4 | quelimane
# Processing Record 45 of Set 4 | ayagoz
# Processing Record 46 of Set 4 | buchanan
# Processing Record 47 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 4 | port alfred
# Processing Record 49 of Set 4 | vazante
# Processing Record 50 of Set 4 | belyy yar
# Processing Record 1 of Set 5 | ahipara
# Processing Record 2 of Set 5 | serebryansk
# Processing Record 3 of Set 5 | severo-kurilsk
# Processing Record 4 of Set 5 | bambous virieux
# Processing Record 5 of Set 5 | goderich
# Processing Record 6 of Set 5 | miguel calmon
# Processing Record 7 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 5 | semey
# Processing Record 9 of Set 5 | bandarbeyla
# Processing Record 10 of Set 5 | worthington
# Processing Record 11 of Set 5 | petrovac
# Processing Record 12 of Set 5 | port augusta
# Processing Record 13 of Set 5 | terra santa
# Processing Record 14 of Set 5 | okhotsk
# Processing Record 15 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 5 | cabo san lucas
# Processing Record 17 of Set 5 | hattiesburg
# Processing Record 18 of Set 5 | altamont
# Processing Record 19 of Set 5 | sisimiut
# Processing Record 20 of Set 5 | kapaa
# Processing Record 21 of Set 5 | nong khai
# Processing Record 22 of Set 5 | saint-francois
# Processing Record 23 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 24 of Set 5 | naryan-mar
# Processing Record 25 of Set 5 | karpogory
# Processing Record 26 of Set 5 | tura
# Processing Record 27 of Set 5 | boguchany
# Processing Record 28 of Set 5 | sokolo
# Processing Record 29 of Set 5 | najran
# Processing Record 30 of Set 5 | bima
# Processing Record 31 of Set 5 | nandgaon
# Processing Record 32 of Set 5 | chumphon
# Processing Record 33 of Set 5 | tiznit
# Processing Record 34 of Set 5 | tual
# Processing Record 35 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 5 | richards bay
# Processing Record 37 of Set 5 | acarau
# Processing Record 38 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 39 of Set 5 | kaeo
# Processing Record 40 of Set 5 | fukue
# Processing Record 41 of Set 5 | bathsheba
# Processing Record 42 of Set 5 | tula
# Processing Record 43 of Set 5 | san patricio
# Processing Record 44 of Set 5 | bakchar
# Processing Record 45 of Set 5 | kisoro
# Processing Record 46 of Set 5 | flin flon
# Processing Record 47 of Set 5 | pevek
# Processing Record 48 of Set 5 | huarmey
# Processing Record 49 of Set 5 | karratha
# Processing Record 50 of Set 5 | autazes
# Processing Record 1 of Set 6 | dudinka
# Processing Record 2 of Set 6 | pochutla
# Processing Record 3 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 6 | kavieng
# Processing Record 5 of Set 6 | minden
# Processing Record 6 of Set 6 | araouane
# Processing Record 7 of Set 6 | maracaibo
# Processing Record 8 of Set 6 | comodoro rivadavia
# Processing Record 9 of Set 6 | fairbanks
# Processing Record 10 of Set 6 | ostrovnoy
# Processing Record 11 of Set 6 | bilibino
# Processing Record 12 of Set 6 | madisonville
# Processing Record 13 of Set 6 | narsaq
# Processing Record 14 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 6 | aklavik
# Processing Record 16 of Set 6 | adoni
# Processing Record 17 of Set 6 | kurilsk
# Processing Record 18 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 6 | arinos
# Processing Record 20 of Set 6 | smithers
# Processing Record 21 of Set 6 | cidreira
# Processing Record 22 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 23 of Set 6 | port blair
# Processing Record 24 of Set 6 | newala
# Processing Record 25 of Set 6 | cockburn town
# Processing Record 26 of Set 6 | nemuro
# Processing Record 27 of Set 6 | kjollefjord
# Processing Record 28 of Set 6 | lalmohan
# Processing Record 29 of Set 6 | upernavik
# Processing Record 30 of Set 6 | altay
# Processing Record 31 of Set 6 | amalapuram
# Processing Record 32 of Set 6 | bengkulu
# Processing Record 33 of Set 6 | isangel
# Processing Record 34 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 6 | sitka
# Processing Record 36 of Set 6 | hornepayne
# Processing Record 37 of Set 6 | katsuura
# Processing Record 38 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 39 of Set 6 | namatanai
# Processing Record 40 of Set 6 | puerto palomas
# Processing Record 41 of Set 6 | anadyr
# Processing Record 42 of Set 6 | coihueco
# Processing Record 43 of Set 6 | taldan
# Processing Record 44 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 6 | sioux lookout
# Processing Record 46 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 6 | eureka
# Processing Record 48 of Set 6 | touros
# Processing Record 49 of Set 6 | lebu
# Processing Record 50 of Set 6 | zyryanka
# Processing Record 1 of Set 7 | clyde river
# Processing Record 2 of Set 7 | guerrero negro
# Processing Record 3 of Set 7 | sorland
# Processing Record 4 of Set 7 | mandera
# Processing Record 5 of Set 7 | wanning
# Processing Record 6 of Set 7 | payo
# Processing Record 7 of Set 7 | tazovskiy
# Processing Record 8 of Set 7 | port macquarie
# Processing Record 9 of Set 7 | coquimbo
# Processing Record 10 of Set 7 | dakar
# Processing Record 11 of Set 7 | puerto del rosario
# Processing Record 12 of Set 7 | caravelas
# Processing Record 13 of Set 7 | tucuman
# Processing Record 14 of Set 7 | salalah
# Processing Record 15 of Set 7 | santiago del estero
# Processing Record 16 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 17 of Set 7 | kangaatsiaq
# Processing Record 18 of Set 7 | sakleshpur
# Processing Record 19 of Set 7 | kismayo
# Processing Record 20 of Set 7 | silver city
# Processing Record 21 of Set 7 | belmonte
# Processing Record 22 of Set 7 | lagoa
# Processing Record 23 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 24 of Set 7 | olafsvik
# Processing Record 25 of Set 7 | samarai
# Processing Record 26 of Set 7 | roznov
# Processing Record 27 of Set 7 | san pedro
# Processing Record 28 of Set 7 | tayoltita
# Processing Record 29 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 30 of Set 7 | lively
# Processing Record 31 of Set 7 | gold coast
# Processing Record 32 of Set 7 | manado
# Processing Record 33 of Set 7 | chunskiy
# Processing Record 34 of Set 7 | yulara
# Processing Record 35 of Set 7 | axim
# Processing Record 36 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 7 | sabla
# Processing Record 38 of Set 7 | tiksi
# Processing Record 39 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 7 | komsomolskiy
# Processing Record 41 of Set 7 | namibe
# Processing Record 42 of Set 7 | port hardy
# Processing Record 43 of Set 7 | oksfjord
# Processing Record 44 of Set 7 | la ronge
# Processing Record 45 of Set 7 | broken hill
# Processing Record 46 of Set 7 | tete
# Processing Record 47 of Set 7 | le vauclin
# Processing Record 48 of Set 7 | marawi
# Processing Record 49 of Set 7 | arman
# Processing Record 50 of Set 7 | alice springs
# Processing Record 1 of Set 8 | hasaki
# Processing Record 2 of Set 8 | tuatapere
# Processing Record 3 of Set 8 | gairo
# Processing Record 4 of Set 8 | aswan
# Processing Record 5 of Set 8 | kashira
# Processing Record 6 of Set 8 | raudeberg
# Processing Record 7 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 8 of Set 8 | kulhudhuffushi
# Processing Record 9 of Set 8 | danielskuil
# Processing Record 10 of Set 8 | omboue
# Processing Record 11 of Set 8 | leningradskiy
# Processing Record 12 of Set 8 | garissa
# Processing Record 13 of Set 8 | ziro
# Processing Record 14 of Set 8 | ancud
# Processing Record 15 of Set 8 | chino valley
# Processing Record 16 of Set 8 | finschhafen
# Processing Record 17 of Set 8 | jishou
# Processing Record 18 of Set 8 | dzilam gonzalez
# Processing Record 19 of Set 8 | umm lajj
# Processing Record 20 of Set 8 | saint-augustin
# Processing Record 21 of Set 8 | cuautepec
# Processing Record 22 of Set 8 | vilcun
# Processing Record 23 of Set 8 | rawalpindi
# Processing Record 24 of Set 8 | carballo
# Processing Record 25 of Set 8 | salto
# Processing Record 26 of Set 8 | jumla
# Processing Record 27 of Set 8 | maydolong
# Processing Record 28 of Set 8 | abha
# Processing Record 29 of Set 8 | meadow lake
# Processing Record 30 of Set 8 | faanui
# Processing Record 31 of Set 8 | saint paul
# Processing Record 32 of Set 8 | acapulco
# Processing Record 33 of Set 8 | cayenne
# Processing Record 34 of Set 8 | zhanaozen
# Processing Record 35 of Set 8 | marsh harbour
# Processing Record 36 of Set 8 | henties bay
# Processing Record 37 of Set 8 | ambon
# Processing Record 38 of Set 8 | darnah
# Processing Record 39 of Set 8 | adrar
# Processing Record 40 of Set 8 | hofn
# Processing Record 41 of Set 8 | entre rios
# Processing Record 42 of Set 8 | evensk
# Processing Record 43 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 8 | coxim
# Processing Record 45 of Set 8 | braslav
# City not found. Skipping...
# Processing Record 46 of Set 8 | otradnoye
# Processing Record 47 of Set 8 | yumen
# Processing Record 48 of Set 8 | kutum
# Processing Record 49 of Set 8 | rio grande
# Processing Record 50 of Set 8 | kimbe
# Processing Record 1 of Set 9 | sudislavl
# Processing Record 2 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 9 | maniitsoq
# Processing Record 4 of Set 9 | yerbogachen
# Processing Record 5 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 9 | pangody
# Processing Record 7 of Set 9 | boyolangu
# Processing Record 8 of Set 9 | mayumba
# Processing Record 9 of Set 9 | bay-khaak
# Processing Record 10 of Set 9 | pavlodar
# Processing Record 11 of Set 9 | berbera
# Processing Record 12 of Set 9 | kiunga
# Processing Record 13 of Set 9 | awbari
# Processing Record 14 of Set 9 | korla
# Processing Record 15 of Set 9 | port keats
# Processing Record 16 of Set 9 | morondava
# Processing Record 17 of Set 9 | sao felix do xingu
# Processing Record 18 of Set 9 | saint-georges
# Processing Record 19 of Set 9 | latung
# Processing Record 20 of Set 9 | lahat
# Processing Record 21 of Set 9 | guangyuan
# Processing Record 22 of Set 9 | mingaora
# Processing Record 23 of Set 9 | presidencia roque saenz pena
# Processing Record 24 of Set 9 | thouars
# Processing Record 25 of Set 9 | voh
# Processing Record 26 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 27 of Set 9 | khandyga
# Processing Record 28 of Set 9 | fortuna
# Processing Record 29 of Set 9 | ponta do sol
# Processing Record 30 of Set 9 | ongandjera
# Processing Record 31 of Set 9 | aguimes
# Processing Record 32 of Set 9 | asfi
# Processing Record 33 of Set 9 | avanigadda
# Processing Record 34 of Set 9 | nizhneangarsk
# Processing Record 35 of Set 9 | valdivia
# Processing Record 36 of Set 9 | villazon
# Processing Record 37 of Set 9 | the valley
# Processing Record 38 of Set 9 | visby
# Processing Record 39 of Set 9 | erdenet
# Processing Record 40 of Set 9 | mizdah
# Processing Record 41 of Set 9 | pareora
# Processing Record 42 of Set 9 | thayetmyo
# Processing Record 43 of Set 9 | neuquen
# Processing Record 44 of Set 9 | grindavik
# Processing Record 45 of Set 9 | grand gaube
# Processing Record 46 of Set 9 | buon me thuot
# City not found. Skipping...
# Processing Record 47 of Set 9 | bundaberg
# Processing Record 48 of Set 9 | ouegoa
# Processing Record 49 of Set 9 | osa
# Processing Record 50 of Set 9 | margate
# Processing Record 1 of Set 10 | touba
# Processing Record 2 of Set 10 | kaputa
# Processing Record 3 of Set 10 | waidhofen
# Processing Record 4 of Set 10 | vostok
# Processing Record 5 of Set 10 | santa rosa
# Processing Record 6 of Set 10 | tartus
# Processing Record 7 of Set 10 | kamina
# Processing Record 8 of Set 10 | mount pleasant
# Processing Record 9 of Set 10 | mbuji-mayi
# Processing Record 10 of Set 10 | carauari
# Processing Record 11 of Set 10 | azrow
# City not found. Skipping...
# Processing Record 12 of Set 10 | duldurga
# Processing Record 13 of Set 10 | iqaluit
# Processing Record 14 of Set 10 | irmo
# Processing Record 15 of Set 10 | mayskiy
# Processing Record 16 of Set 10 | coolum beach
# Processing Record 17 of Set 10 | yar-sale
# Processing Record 18 of Set 10 | preobrazheniye
# Processing Record 19 of Set 10 | sovetskaya gavan
# Processing Record 20 of Set 10 | bulgan
# Processing Record 21 of Set 10 | calvinia
# Processing Record 22 of Set 10 | ambilobe
# Processing Record 23 of Set 10 | whitianga
# Processing Record 24 of Set 10 | thompson
# Processing Record 25 of Set 10 | havre
# Processing Record 26 of Set 10 | normandin
# Processing Record 27 of Set 10 | tondano
# Processing Record 28 of Set 10 | sur
# Processing Record 29 of Set 10 | westport
# Processing Record 30 of Set 10 | deniliquin
# Processing Record 31 of Set 10 | arawa
# Processing Record 32 of Set 10 | sinnamary
# Processing Record 33 of Set 10 | berlevag
# Processing Record 34 of Set 10 | college
# Processing Record 35 of Set 10 | codrington
# Processing Record 36 of Set 10 | crotone
# Processing Record 37 of Set 10 | srednekolymsk
# Processing Record 38 of Set 10 | beringovskiy
# Processing Record 39 of Set 10 | arambagh
# Processing Record 40 of Set 10 | sape
# Processing Record 41 of Set 10 | ryotsu
# Processing Record 42 of Set 10 | luganville
# Processing Record 43 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 10 | aitape
# Processing Record 45 of Set 10 | ciro marina
# Processing Record 46 of Set 10 | mitsamiouli
# Processing Record 47 of Set 10 | zhigansk
# Processing Record 48 of Set 10 | cochrane
# Processing Record 49 of Set 10 | kozhevnikovo
# Processing Record 50 of Set 10 | faya
# Processing Record 1 of Set 11 | pinega
# Processing Record 2 of Set 11 | klaksvik
# Processing Record 3 of Set 11 | vernon
# Processing Record 4 of Set 11 | tambovka
# Processing Record 5 of Set 11 | fergus falls
# Processing Record 6 of Set 11 | mach
# Processing Record 7 of Set 11 | ust-kuyga
# Processing Record 8 of Set 11 | milas
# Processing Record 9 of Set 11 | aranos
# Processing Record 10 of Set 11 | matara
# Processing Record 11 of Set 11 | sabya
# Processing Record 12 of Set 11 | anchorage
# Processing Record 13 of Set 11 | ketchikan
# Processing Record 14 of Set 11 | kafanchan
# Processing Record 15 of Set 11 | raga
# Processing Record 16 of Set 11 | ilabaya
# Processing Record 17 of Set 11 | ukiah
# Processing Record 18 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 19 of Set 11 | ust-nera
# Processing Record 20 of Set 11 | manzil tamim
# City not found. Skipping...
# Processing Record 21 of Set 11 | fare
# Processing Record 22 of Set 11 | maarianhamina
# Processing Record 23 of Set 11 | mtambile
# Processing Record 24 of Set 11 | brahmapuri
# City not found. Skipping...
# Processing Record 25 of Set 11 | nanakuli
# Processing Record 26 of Set 11 | meulaboh
# Processing Record 27 of Set 11 | rocha
# Processing Record 28 of Set 11 | bhadasar
# Processing Record 29 of Set 11 | novochernorechenskiy
# Processing Record 30 of Set 11 | sao gabriel da cachoeira
# Processing Record 31 of Set 11 | ixtapa
# Processing Record 32 of Set 11 | norman wells
# Processing Record 33 of Set 11 | juegang
# Processing Record 34 of Set 11 | neepawa
# Processing Record 35 of Set 11 | sungaipenuh
# Processing Record 36 of Set 11 | serchhip
# Processing Record 37 of Set 11 | lata
# Processing Record 38 of Set 11 | ekhabi
# Processing Record 39 of Set 11 | shirgaon
# Processing Record 40 of Set 11 | guarapari
# Processing Record 41 of Set 11 | kayalpattinam
# Processing Record 42 of Set 11 | rio gallegos
# Processing Record 43 of Set 11 | yankton
# Processing Record 44 of Set 11 | borogontsy
# Processing Record 45 of Set 11 | cabanas
# Processing Record 46 of Set 11 | tonneins
# Processing Record 47 of Set 11 | turayf
# Processing Record 48 of Set 11 | campoverde
# Processing Record 49 of Set 11 | kieta
# Processing Record 50 of Set 11 | alamosa
# Processing Record 1 of Set 12 | bubaque
# Processing Record 2 of Set 12 | laurel
# Processing Record 3 of Set 12 | keti bandar
# Processing Record 4 of Set 12 | port lincoln
# Processing Record 5 of Set 12 | valentin gomez farias
# Processing Record 6 of Set 12 | laguna
# Processing Record 7 of Set 12 | puerto princesa
# Processing Record 8 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 9 of Set 12 | fallon
# Processing Record 10 of Set 12 | price
# Processing Record 11 of Set 12 | madang
# Processing Record 12 of Set 12 | kruisfontein
# Processing Record 13 of Set 12 | muros
# Processing Record 14 of Set 12 | gezing
# Processing Record 15 of Set 12 | synya
# Processing Record 16 of Set 12 | luangwa
# Processing Record 17 of Set 12 | aksay
# Processing Record 18 of Set 12 | sao domingos
# Processing Record 19 of Set 12 | susangerd
# Processing Record 20 of Set 12 | sandnessjoen
# Processing Record 21 of Set 12 | fairlie
# Processing Record 22 of Set 12 | svetlogorsk
# Processing Record 23 of Set 12 | halifax
# Processing Record 24 of Set 12 | makiyivka
# Processing Record 25 of Set 12 | brigantine
# Processing Record 26 of Set 12 | thaba nchu
# Processing Record 27 of Set 12 | andenes
# Processing Record 28 of Set 12 | jhalrapatan
# Processing Record 29 of Set 12 | beloha
# Processing Record 30 of Set 12 | santa isabel do rio negro
# Processing Record 31 of Set 12 | tabas
# Processing Record 32 of Set 12 | biak
# Processing Record 33 of Set 12 | pompeia
# Processing Record 34 of Set 12 | bukan
# Processing Record 35 of Set 12 | kerman
# Processing Record 36 of Set 12 | jiangyou
# Processing Record 37 of Set 12 | northam
# Processing Record 38 of Set 12 | asau
# Processing Record 39 of Set 12 | kuruman
# Processing Record 40 of Set 12 | viedma
# Processing Record 41 of Set 12 | hastings
# Processing Record 42 of Set 12 | cocorit
# Processing Record 43 of Set 12 | vardo
# Processing Record 44 of Set 12 | bridlington
# Processing Record 45 of Set 12 | taltal
# Processing Record 46 of Set 12 | sabzevar
# Processing Record 47 of Set 12 | nantucket
# Processing Record 48 of Set 12 | vilaka
# Processing Record 49 of Set 12 | san fernando
# Processing Record 50 of Set 12 | nome
# Processing Record 1 of Set 13 | sabha
# Processing Record 2 of Set 13 | bitlis
# Processing Record 3 of Set 13 | staryy nadym
# Processing Record 4 of Set 13 | maragogi
# Processing Record 5 of Set 13 | birin
# Processing Record 6 of Set 13 | katherine
# Processing Record 7 of Set 13 | harper
# Processing Record 8 of Set 13 | dunedin
# Processing Record 9 of Set 13 | bolshoy lug
# Processing Record 10 of Set 13 | encheng
# Processing Record 11 of Set 13 | burns lake
# Processing Record 12 of Set 13 | moose factory
# Processing Record 13 of Set 13 | jieshi
# Processing Record 14 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 13 | barao de melgaco
# Processing Record 16 of Set 13 | norsup
# Processing Record 17 of Set 13 | lockport
# Processing Record 18 of Set 13 | suntar
# Processing Record 19 of Set 13 | sept-iles
# Processing Record 20 of Set 13 | napier
# Processing Record 21 of Set 13 | seryshevo
# Processing Record 22 of Set 13 | sanlucar la mayor
# Processing Record 23 of Set 13 | bam
# Processing Record 24 of Set 13 | port hawkesbury
# Processing Record 25 of Set 13 | noumea
# Processing Record 26 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 13 | pillaro
# Processing Record 28 of Set 13 | nelson bay
# Processing Record 29 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 13 | mtwara
# Processing Record 31 of Set 13 | dawlatabad
# Processing Record 32 of Set 13 | flinders
# Processing Record 33 of Set 13 | te anau
# Processing Record 34 of Set 13 | bandar
# Processing Record 35 of Set 13 | hay river
# Processing Record 36 of Set 13 | saint-pacome
# City not found. Skipping...
# Processing Record 37 of Set 13 | emerald
# Processing Record 38 of Set 13 | tommot
# Processing Record 39 of Set 13 | mehamn
# Processing Record 40 of Set 13 | athabasca
# Processing Record 41 of Set 13 | abilene
# Processing Record 42 of Set 13 | oga
# Processing Record 43 of Set 13 | riyadh
# Processing Record 44 of Set 13 | boyle
# Processing Record 45 of Set 13 | itamaraca
# Processing Record 46 of Set 13 | rio claro
# Processing Record 47 of Set 13 | nyergesujfalu
# Processing Record 48 of Set 13 | borgarnes
# Processing Record 49 of Set 13 | taoudenni
# Processing Record 50 of Set 13 | orebro
# Processing Record 1 of Set 14 | mapastepec
# Processing Record 2 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 3 of Set 14 | walvis bay
# Processing Record 4 of Set 14 | nizwa
# Processing Record 5 of Set 14 | de-kastri
# Processing Record 6 of Set 14 | balkanabat
# Processing Record 7 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 14 | ballina
# Processing Record 9 of Set 14 | kampot
# Processing Record 10 of Set 14 | ponta delgada
# Processing Record 11 of Set 14 | lake havasu city
# Processing Record 12 of Set 14 | yarovoye
# Processing Record 13 of Set 14 | honiara
# Processing Record 14 of Set 14 | taksimo
# Processing Record 15 of Set 14 | surt
# Processing Record 16 of Set 14 | pitimbu
# Processing Record 17 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 18 of Set 14 | hecun
# Processing Record 19 of Set 14 | lingao
# Processing Record 20 of Set 14 | beira
# Processing Record 21 of Set 14 | claymont
# Processing Record 22 of Set 14 | veraval
# Processing Record 23 of Set 14 | kungurtug
# Processing Record 24 of Set 14 | zhezkazgan
# Processing Record 25 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 14 | porto seguro
# Processing Record 27 of Set 14 | coihaique
# Processing Record 28 of Set 14 | santa maria
# Processing Record 29 of Set 14 | carahue
# Processing Record 30 of Set 14 | eyrarbakki
# Processing Record 31 of Set 14 | grand-lahou
# Processing Record 32 of Set 14 | broome
# Processing Record 33 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 14 | praia
# Processing Record 35 of Set 14 | sistranda
# Processing Record 36 of Set 14 | hangu
# Processing Record 37 of Set 14 | nuuk
# Processing Record 38 of Set 14 | west des moines
# Processing Record 39 of Set 14 | bell ville
# Processing Record 40 of Set 14 | komsomolets
# Processing Record 41 of Set 14 | manokwari
# Processing Record 42 of Set 14 | stornoway
# Processing Record 43 of Set 14 | talara
# Processing Record 44 of Set 14 | nouadhibou
# Processing Record 45 of Set 14 | loiza
# Processing Record 46 of Set 14 | lodwar
# Processing Record 47 of Set 14 | nyurba
# Processing Record 48 of Set 14 | lensk
# Processing Record 49 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 14 | eydhafushi
# Processing Record 1 of Set 15 | janow lubelski
# Processing Record 2 of Set 15 | mersing
# Processing Record 3 of Set 15 | khasan
# Processing Record 4 of Set 15 | sebastian
# Processing Record 5 of Set 15 | pangai
# Processing Record 6 of Set 15 | beaverlodge
# Processing Record 7 of Set 15 | puerto baquerizo moreno
# Processing Record 8 of Set 15 | blythe
# Processing Record 9 of Set 15 | kloulklubed
# Processing Record 10 of Set 15 | proletarsk
# Processing Record 11 of Set 15 | eregli
# Processing Record 12 of Set 15 | barreirinhas
# Processing Record 13 of Set 15 | izhmorskiy
# Processing Record 14 of Set 15 | larap
# Processing Record 15 of Set 15 | banyo
# Processing Record 16 of Set 15 | jalu
# Processing Record 17 of Set 15 | maine-soroa
# Processing Record 18 of Set 15 | tautira
# Processing Record 19 of Set 15 | vredendal
# Processing Record 20 of Set 15 | chicama
# Processing Record 21 of Set 15 | san andres
# Processing Record 22 of Set 15 | kinkala
# Processing Record 23 of Set 15 | antigonish
# Processing Record 24 of Set 15 | boa vista
# Processing Record 25 of Set 15 | road town
# Processing Record 26 of Set 15 | olinda
# Processing Record 27 of Set 15 | zheshart
# Processing Record 28 of Set 15 | chichimila
# Processing Record 29 of Set 15 | dukhovnitskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 671

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Khatanga  71.9667  102.5000     46.53        56           4        3.13
# 1    Souillac -20.5167   57.5167     71.37        77          42       20.07
# 2       Minas -34.3759  -55.2377     55.87        93          49       11.59
# 3         Shu  43.5983   73.7614     62.22        25           8        2.37
# 4  Mahibadhoo   3.7833   72.9667     82.18        73          38       10.27
# 5   Busselton -33.6500  115.3333     55.04        61          16        6.31
# 6   Ambovombe -25.1667   46.0833     65.77        84          17       14.00
# 7       Orsha  54.5153   30.4053     56.21        78         100        5.55
# 8     Rikitea -23.1203 -134.9692     74.30        72          88        9.33
# 9   Mahebourg -20.4081   57.7000     71.26        76          23       21.12
#
#   Country                 Date Current Description
# 0      RU  2021-09-12 02:04:59           clear sky
# 1      MU  2021-09-12 02:07:37    scattered clouds
# 2      UY  2021-09-12 02:07:37    scattered clouds
# 3      KZ  2021-09-12 02:07:37           clear sky
# 4      MV  2021-09-12 02:07:38    scattered clouds
# 5      AU  2021-09-12 02:07:39          few clouds
# 6      MG  2021-09-12 02:07:39          few clouds
# 7      BY  2021-09-12 02:07:39     overcast clouds
# 8      PF  2021-09-12 02:07:40     overcast clouds
# 9      MU  2021-09-12 02:03:53          few clouds

# %%
cols_new_order = ['City','Country','Date','Lat','Lng','Max Temp','Humidity', 'Cloudiness','Wind Speed', 'Current Description']
city_data_df=city_data_df[cols_new_order]
city_data_df.head(10)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0    Khatanga      RU  2021-09-12 02:04:59  71.9667  102.5000     46.53
# 1    Souillac      MU  2021-09-12 02:07:37 -20.5167   57.5167     71.37
# 2       Minas      UY  2021-09-12 02:07:37 -34.3759  -55.2377     55.87
# 3         Shu      KZ  2021-09-12 02:07:37  43.5983   73.7614     62.22
# 4  Mahibadhoo      MV  2021-09-12 02:07:38   3.7833   72.9667     82.18
# 5   Busselton      AU  2021-09-12 02:07:39 -33.6500  115.3333     55.04
# 6   Ambovombe      MG  2021-09-12 02:07:39 -25.1667   46.0833     65.77
# 7       Orsha      BY  2021-09-12 02:07:39  54.5153   30.4053     56.21
# 8     Rikitea      PF  2021-09-12 02:07:40 -23.1203 -134.9692     74.30
# 9   Mahebourg      MU  2021-09-12 02:03:53 -20.4081   57.7000     71.26
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        56           4        3.13           clear sky
# 1        77          42       20.07    scattered clouds
# 2        93          49       11.59    scattered clouds
# 3        25           8        2.37           clear sky
# 4        73          38       10.27    scattered clouds
# 5        61          16        6.31          few clouds
# 6        84          17       14.00          few clouds
# 7        78         100        5.55     overcast clouds
# 8        72          88        9.33     overcast clouds
# 9        76          23       21.12          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
